# %%
import internship_search_index

# %%
index = internship_search_index.create_inverted_index()

# %%
index
# Out:
# {'data': [['Data Scientist (Stage ou Alternance)', 0.10767957614538781],
#   ['FeDT: A Federation of Digital Twins for Sustainability in the E4C Ecosystem',
#    0.08949990744551715],
#   ['Development of a RAG (Retrieval Augmented Generation) pipeline to facilitate access and reuse of open-data',
#    0.07458325620459763],
#   ['Differential Privacy for Epidemic Surveillance', 0.057911704817687565],
#   ['A Data-Driven Time-Series Analysis for the Impact of External Factors on Energy Consumption and Greenhouse Gas Emissions of Taxis',
#    0.05350537945112438],
#   ['Optimal Transport for Anomaly Detection and Localization',
#    0.051815735889509926],
#   ['Cybersécurité -Simulation de données réseaux', 0.049224949095034436],
#   ['Enabling XAI in IoT-enhanced Spaces', 0.04474995372275858],
#   ['Automated machine learning for batch and stream settings',
#    0.04018363191431382],
#   ['Deep learning with Normalizing Flows for anomaly detection on time series',
# ...

# %%
index['vision']
# Out:
# [['Computer vision - Image segmentation for Urban scene Analysis',
#   0.19730379672781054],
#  ['Pré-traitement d’images en temps réel pour corriger le flou de mouvement et une mauvaise exposition\xa0: application à la robotique agricole en extérieur.',
#   0.10687288989423069],
#  ['Transfert d’apprentissage et connectivité de modes inter-tâches',
#   0.0884465295676392],
#  ['Measuring canopy height and assessing Ciaran storm damage on forest using satellite imagery and LiDAR',
#   0.058964353045092795],
#  ["Stage R&D (Vision par ordinateur) - Suivi du stylo pour la rééducation de l'écriture manuscrite",
#   0.03166604145014243],
#  ['Automated machine learning for batch and stream settings',
#   0.020938362101726834],
#  ['Stagiaire - Approximation robuste d’indicateurs pour accélérer la transition agroécologique',
#   0.010732005679755383]]

# %%
index.keys()
# Out:
# dict_keys(['data', 'dat', 'scientist', 'stage', 'stag', 'ou', 'altern', 'jungl', 'bike', 'bik', 'alic', 'battarel', 'scienc', 'compani', 'company', 'focus', 'focused', 'cycl', 'cycling', 'industri', 'industry', 'offer', 'offering', 'month', 'internship', 'apprenticeship', 'intern', 'work', 'various', 'project', 'includ', 'including', 'analysi', 'analys', 'prepar', 'featur', 'engin', 'engineering', 'predict', 'model', 'modeling', 'machin', 'learn', 'learning', 'ideal', 'candid', 'candidat', 'student', 'background', 'relat', 'related', 'field', 'experi', 'experient', 'profici', 'proficiency', 'python', 'sql', 'base', 'based', 'pari', 'paris', 'close', 'closely', 'ceo', 'cto', 'team', 'member', 'account', 'accounting', 'brain', 'electr', 'electrical', 'stimul', 'reinforc', 'cnrs', 'cnr', 'alexandr', 'muzi', 'muzy', 'propos', 'proposal', 'research', 'goal', 'develop', 'new', 'understand', 'impact', 'assess', 'assessed', 'synthet', 'synthetic', 'appli', 'applied', 'real', 'exper', 'involv
# ...

# %%
index['psl']
# Out:
# [['Hexago', 0.10271043783826997],
#  ['Deep learning algorithms for large and robust models', 0.0736091471174268],
#  ['Privacy in Overparametrized Machine Learning Models', 0.06900857542258763],
#  ['LLM learning : beyond backpropagation', 0.06794690503147091],
#  ['Multimodal Monte Carlo Tree Search', 0.06794690503147091],
#  ['Automatic Refutation of Graph Theory Conjectures', 0.06591863920963595],
#  ['Differential Privacy for Epidemic Surveillance', 0.06494924745655306],
#  ['Incremental Elicitation Relying on Monte Carlo Tree Search Techniques',
#   0.06400795401515375],
#  ['Algorithmes de recherche arborescente pour la résolution du problème de tournées de techniciens',
#   0.053211431651151914],
#  ['Automatisation des matchs à l’aide de Discord pour les Jeux de Société Olympiques entre intelligences artificielles',
#   0.053211431651151914]]
